# %% [markdown]
# # COVID-19 Data Analysis & Visualizations
#
# Step 1: Load Multiple Datasets (Covid_19_india & Covid_19_Vaccine_Statewise)
#
# Step 2: Data Cleaning, Preprocessing and Data Extracting
#
# Step 3: Create Pivot table in Statewise Deaths, Cured, Confirmed, Recovery Rate and Mortality Rate.
#
# Step 4: Vaccinated Analysis
#
# Step 5: Data Visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df=pd.read_csv("D:\Covid 19 in India(03-05-2024)/covid_19_india (1).csv")

# %%
covid_df.head(10)
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  18110  11-08-2021  8:00 AM          West Bengal                       -
# 1  18109  11-08-2021  8:00 AM        Uttar Pradesh                       -
# 2  18108  11-08-2021  8:00 AM          Uttarakhand                       -
# 3  18107  11-08-2021  8:00 AM              Tripura                       -
# 4  18106  11-08-2021  8:00 AM            Telangana                       -
# 5  18105  11-08-2021  8:00 AM           Tamil Nadu                       -
# 6  18104  11-08-2021  8:00 AM               Sikkim                       -
# 7  18103  11-08-2021  8:00 AM            Rajasthan                       -
# 8  18102  11-08-2021  8:00 AM               Punjab                       -
# 9  18101  11-08-2021  8:00 AM           Puducherry                       -
#
#   ConfirmedForeignNational    Cured  Deaths  Confirmed
# 0                        -  1506532   18252    1534999
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
covid_df.describe().T
# Out:
#              count           mean            std  min      25%      50%  \
# Sno        18110.0    9055.500000    5228.051023  1.0  4528.25   9055.5
# Cured      18110.0  278637.518056  614890.894424  0.0  3360.25  33364.0
# Deaths     18110.0    4052.402264   10919.076411  0.0    32.00    588.0
# Confirmed  18110.0  301031.401822  656148.872965  0.0  4376.75  39773.5
#
#                  75%        max
# Sno         13582.75    18110.0
# Cured      278869.75  6159676.0
# Deaths       3643.75   134201.0
# Confirmed  300149.75  6363442.0

# %%
vaccine_df=pd.read_csv('D:\Covid 19 in India(03-05-2024)/covid_vaccine_statewise.csv')

# %%
vaccine_df.head(7)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
# 5  21/01/2021  India                  365965.0   32226.0  12600.0
# 6  22/01/2021  India                  549381.0   36988.0  14115.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
# 5                 365965.0                       0.0
# 6                 549381.0                       0.0
#
# ...

# %%
covid_df.drop(["Sno","Time","ConfirmedIndianNational","ConfirmedForeignNational"],inplace=True,axis=1)

# %%
covid_df.head()
# Out:
#          Date State/UnionTerritory    Cured  Deaths  Confirmed
# 0  11-08-2021          West Bengal  1506532   18252    1534999
# 1  11-08-2021        Uttar Pradesh  1685492   22775    1708812
# 2  11-08-2021          Uttarakhand   334650    7368     342462
# 3  11-08-2021              Tripura    77811     773      80660
# 4  11-08-2021            Telangana   638410    3831     650353

# %%
import warnings
warnings.filterwarnings('ignore')
covid_df["Date"]=pd.to_datetime(covid_df["Date"])

# %%
covid_df.head()
# Out:
#         Date State/UnionTerritory    Cured  Deaths  Confirmed
# 0 2021-11-08          West Bengal  1506532   18252    1534999
# 1 2021-11-08        Uttar Pradesh  1685492   22775    1708812
# 2 2021-11-08          Uttarakhand   334650    7368     342462
# 3 2021-11-08              Tripura    77811     773      80660
# 4 2021-11-08            Telangana   638410    3831     650353

# %%
#Find Active Cases

covid_df["Active_Cases"]=covid_df['Confirmed'] - (covid_df['Cured'] + covid_df["Deaths"])
covid_df.tail()
# Out:
#             Date State/UnionTerritory  Cured  Deaths  Confirmed  Active_Cases
# 18105 2020-03-02               Kerala      0       0          3             3
# 18106 2020-02-02               Kerala      0       0          3             3
# 18107 2020-01-02               Kerala      0       0          2             2
# 18108 2020-01-31               Kerala      0       0          1             1
# 18109 2020-01-30               Kerala      0       0          1             1

# %%
# Creating Pivot Table
Statewise=pd.pivot_table(covid_df,values=['Confirmed','Deaths','Cured'],index='State/UnionTerritory',aggfunc=max)

# %%
Statewise["Recovery Rate"]=Statewise['Cured']*100/Statewise['Confirmed']

# %%
Statewise["Mortality Rate"]=Statewise['Deaths']*100/Statewise['Confirmed']

# %%
Statewise=Statewise.sort_values(by="Confirmed",ascending=False)

# %%
Statewise.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_ba478_row0_col0, #T_ba478_row0_col1, #T_ba478_row0_col2, #T_ba478_row20_col4, #T_ba478_row39_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ba478_row0_col3, #T_ba478_row31_col3 {
#   background-color: #f0fbf5;
#   color: #000000;
# }
# #T_ba478_row0_col4 {
#   background-color: #c3bff2;
#   color: #000000;
# }
# #T_ba478_row1_col0, #T_ba478_row3_col3, #T_ba478_row4_col3, #T_ba478_row5_col3, #T_ba478_row24_col3, #T_ba478_row27_col3, #T_ba478_row28_col3, #T_ba478_row29_col3 {
#   background-color: #f6fcf8;
#   color: #000000;
# }
# #T_ba478_row1_col1, #T_ba478_row1_col2, #T_ba478_row20_col3, #T_ba478_row26_col3 {
#   background-color: #f4fcf7;
#   color: #000000;
# }
# #T_ba478_row1_col3 {
#   background-color: #effaf4;
#   color: #000000;
# }
# #T_ba478_row1_col4 {
#   background-color: #c4bdf1;
#   color: #000000;
# }
# #T_ba478_row2_col0 {
#   background-color: #c57a76;
#   color: #f1f1f1;
# }
# #T_ba478_row2_col1 {
# ...

# %%
Top_10_Active_Cases=covid_df.groupby(by='State/UnionTerritory').max()[['Active_Cases','Date']].sort_values(by=["Active_Cases"],
                    ascending=False).reset_index()
fig=plt.figure(figsize=(16,9))
plt.title("Top 10 States with Most Active Cases in India",size=25)
ax=sns.barplot(data=Top_10_Active_Cases.iloc[:10],y="Active_Cases",x='State/UnionTerritory',linewidth=2,edgecolor="black"
               ,palette="OrRd")
plt.xlabel('States')
plt.ylabel("Total Active Cases")
plt.show()

# %%
# Top 10 Deaths in Statewise
Top_10_Deaths=covid_df.groupby(by='State/UnionTerritory').max()[['Deaths','Date']].sort_values(by="Deaths",
                                                                                               ascending=False).reset_index()
fig=plt.figure(figsize=(18,6))
plt.title("Top 10 States with most Deaths",size=25)
ax=sns.barplot(data=Top_10_Deaths.iloc[:12],x="State/UnionTerritory",y="Deaths",linewidth=2,edgecolor='black',palette="RdPu")
plt.xlabel("States")
plt.ylabel("Total Death Cases")
plt.show()

# %%
# Growth trend
fig=plt.figure(figsize=(15,6))
ax=sns.lineplot(x='Date',y='Active_Cases',hue='State/UnionTerritory',
                data=covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra', 'Karnataka', 'Kerala', 'Tamil Nadu', 
                                                                     'Uttar Pradesh'])])
ax.set_title("Top 5 Affected States in India")
plt.show()

# %%
vaccine_df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
vaccine_df.rename(columns={'Updated On':'Vaccine_Date'},inplace=True)

# %%
vaccine_df.head(10)
# Out:
#   Vaccine_Date  State  Total Doses Administered  Sessions   Sites   \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
# 5   21/01/2021  India                  365965.0   32226.0  12600.0
# 6   22/01/2021  India                  549381.0   36988.0  14115.0
# 7   23/01/2021  India                  759008.0   43076.0  15605.0
# 8   24/01/2021  India                  835058.0   49851.0  18111.0
# 9   25/01/2021  India                 1277104.0   55151.0  19682.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# ...

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Vaccine_Date                         7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
vaccine_df.isnull().sum()
# Out:
# Vaccine_Date                              0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
vaccination=vaccine_df.drop(columns=['Sputnik V (Doses Administered)','AEFI','18-44 Years (Doses Administered)',
                                     '45-60 Years (Doses Administered)','60+ Years (Doses Administered)'])

# %%
vaccination.head()
# Out:
#   Vaccine_Date  State  Total Doses Administered  Sessions   Sites   \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
# Remove rows where state is india
vaccine=vaccine_df[vaccine_df.State !='India']
vaccine.head()
# Out:
#     Vaccine_Date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# 214       9.0      2.0                     42.0                       0.0
# 215      12.0      2.0                     89.0                       0.0
# 216      16.0      3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
vaccine.rename(columns={'Total Individuals Vaccinated':"Total"},inplace=True)
vaccine.head()
# Out:
#     Vaccine_Date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# 214       9.0      2.0                     42.0                       0.0
# 215      12.0      2.0                     89.0                       0.0
# 216      16.0      3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
# Most Vaccinated State
max_vac=vaccine.groupby("State")['Total'].sum().to_frame('Total')
max_vac=max_vac.sort_values('Total',ascending=False)[:5]
max_vac
# Out:
#                       Total
# State
# Maharashtra    1.403075e+09
# Uttar Pradesh  1.200575e+09
# Rajasthan      1.141163e+09
# Gujarat        1.078261e+09
# West Bengal    9.250227e+08

# %%
plt.figure(figsize=(15,6))
ax=sns.barplot(data=max_vac.iloc[:5],x=max_vac.index,y='Total',palette="Blues")
plt.title('Top 5 Vaccinated States')
plt.show()

# %%
min_vac=vaccine.groupby('State')['Total'].sum().to_frame('Total')
min_vac=min_vac.sort_values('Total',ascending=True)[:5]
min_vac
# Out:
#                                                Total
# State
# Lakshadweep                                2124715.0
# Andaman and Nicobar Islands                8102125.0
# Ladakh                                     9466289.0
# Dadra and Nagar Haveli and Daman and Diu  11358600.0
# Sikkim                                    16136752.0

# %%
plt.figure(figsize=(15,6))
ax=sns.barplot(data=min_vac.iloc[:5],x=min_vac.index,y="Total",palette='Greens')
plt.show()
